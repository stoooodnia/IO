# %%
import pandas as pd

miasta = pd.read_csv('./miasta.csv')
print(miasta)
# Out:
#     Rok  Gdansk  Poznan  Szczecin
# 0  1900     170     110       210
# 1  1925     210     220       254
# 2  1939     250     274       287
# 3  1946     117     267        72
# 4  1950     194     320       178
# 5  1960     286     408       269
# 6  1970     365     471       338
# 7  1980     456     552       388
# 8  1990     465     590       413
# 9  2000     462     574       416

# %%
nowyWiersz = {'Rok': '2010','Gdansk':'460','Poznan':'555','Szczecin':'405'}
miasta = miasta.append(nowyWiersz, ignore_index=True)
print(miasta)
# Out:
#      Rok Gdansk Poznan Szczecin
# 0   1900    170    110      210
# 1   1925    210    220      254
# 2   1939    250    274      287
# 3   1946    117    267       72
# 4   1950    194    320      178
# 5   1960    286    408      269
# 6   1970    365    471      338
# 7   1980    456    552      388
# 8   1990    465    590      413
# 9   2000    462    574      416
# 10  2010    460    555      405
# 11  2010    460    555      405
# /var/folders/2n/z74nb9cn4kl60b3mjj5lgz140000gn/T/ipykernel_14835/756111225.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   miasta = miasta.append(nowyWiersz, ignore_index=True)

# %%
import matplotlib.pyplot as plt
x = miasta['Rok'].values
y = miasta['Gdansk'].values
print(x)
print(y)
plt.plot(x,y,'r') 
plt.xlabel('Rok')
plt.ylabel('Liczba ludnosci')
plt.show()
# Out:
# [1900 1925 1939 1946 1950 1960 1970 1980 1990 2000 '2010' '2010']
# [170 210 250 117 194 286 365 456 465 462 '460' '460']
